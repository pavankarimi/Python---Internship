# %%
tup=(10,20,30,40)
print(tup)
# Out:
# (10, 20, 30, 40)

# %% [markdown]
# # Tuple Functions

# %%
print("Len : ",len(tup))
# Out:
# Len :  4

# %%
print("Max : ",max(tup))
# Out:
# Max :  40

# %%
print("Min : ",min(tup))
# Out:
# Min :  10

# %%
print("Sum : ",sum(tup))
# Out:
# Sum :  100

# %%
print("Reversed : ",tuple(reversed(tup)))
# Out:
# Reversed :  (40, 30, 20, 10)

# %%
tup
# Out:
# (10, 20, 30, 40)

# %%
print("Sorted : ", sorted(tup))
# Out:
# Sorted :  [10, 20, 30, 40]

# %%
l=[10,50,60,20]
print(l, "Data Type", type(l))
res = tuple(l)
print(res, "Data Type", type(res))
# Out:
# [10, 50, 60, 20] Data Type <class 'list'>
# (10, 50, 60, 20) Data Type <class 'tuple'>

# %%
tup
# Out:
# (10, 20, 30, 40)

# %%
for index,value in enumerate(tup):
    print("Index : ",index,"  Value :" ,value)
# Out:
# Index :  0   Value : 10
# Index :  1   Value : 20
# Index :  2   Value : 30
# Index :  3   Value : 40

# %%
for i in range(len(tup)):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# # Tuple Methods

# %%
print("count : ", tup.count(10))
# Out:
# count :  1

# %%
tup=(10,20,10,30,40)
print("index : ", tup.index(30))
# Out:
# index :  3
